# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv ( "C:/users/hp/downloads/diabetes_risk_prediction_dataset.csv")
df.head(5)
# Out:
#    Patient_ID   Age Gender        Country  Height_cm  Weight_kg   BMI  \
# 0           1  32.0   Male         Mexico      182.1       65.8  19.8
# 1           2  42.0  Other   Saudi Arabia      148.5      101.2  45.9
# 2           3  89.0  Other      Argentina      158.1        NaN  37.9
# 3           4  87.0  Other  United States      190.9       95.9  26.3
# 4           5  27.0  Other      Australia      156.9      101.9  41.4
#
#    Waist_Circumference_cm  Blood_Glucose  HbA1c  ...  Fatty_Liver  PCOS  \
# 0                    71.2           88.4   10.4  ...          Yes    No
# 1                   121.8          247.3   11.3  ...          Yes   Yes
# 2                   131.8          141.9    6.3  ...          Yes    No
# 3                    99.1           90.1    7.4  ...           No    No
# 4                    77.1           93.8   12.0  ...          Yes   Yes
#
#    Medication_Adherence   Work_Type  Residence_Type  Daily_Water_Intake_L  \
# ...

# %% [markdown]
# ## Handling missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Patient_ID                  50000 non-null  int64
#  1   Age                         49503 non-null  float64
#  2   Gender                      50000 non-null  object
#  3   Country                     50000 non-null  object
#  4   Height_cm                   47055 non-null  float64
#  5   Weight_kg                   47038 non-null  float64
#  6   BMI                         50000 non-null  float64
#  7   Waist_Circumference_cm      50000 non-null  float64
#  8   Blood_Glucose               49041 non-null  float64
#  9   HbA1c                       48026 non-null  float64
#  10  Fasting_Blood_Sugar         50000 non-null  float64
#  11  Insulin_Level               50000 non-null  float64
#  12  Blood_Pressure_Systolic     50000 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Patient_ID                       0
# Age                            497
# Gender                           0
# Country                          0
# Height_cm                     2945
# Weight_kg                     2962
# BMI                              0
# Waist_Circumference_cm           0
# Blood_Glucose                  959
# HbA1c                         1974
# Fasting_Blood_Sugar              0
# Insulin_Level                    0
# Blood_Pressure_Systolic          0
# Blood_Pressure_Diastolic         0
# Total_Cholesterol             1000
# HDL                           1000
# LDL                           1000
# Triglycerides                 1000
# Heart_Rate                       0
# Physical_Activity_Level        500
# Exercise_Hours_Per_Week       1992
# Daily_Walking_Minutes         1964
# Diet_Quality                     0
# Sugar_Intake_Level               0
# Sleep_Hours                   2017
# Stress_Level                     0
# Smoking_Status                   0
# ...

# %%
df.describe()
# Out:
#          Patient_ID           Age     Height_cm     Weight_kg           BMI  \
# count  50000.000000  49503.000000  47055.000000  47038.000000  50000.000000
# mean   25000.500000     53.871099    170.018814     87.457003     30.924056
# std    14433.901067     21.130148     14.457787     24.500358     10.290091
# min        1.000000     18.000000    145.000000     45.000000     11.900000
# 25%    12500.750000     35.000000    157.600000     66.300000     22.700000
# 50%    25000.500000     54.000000    170.000000     87.300000     30.000000
# 75%    37500.250000     72.000000    182.600000    108.600000     37.800000
# max    50000.000000     90.000000    195.000000    130.000000     61.700000
#
#        Waist_Circumference_cm  Blood_Glucose         HbA1c  \
# count            50000.000000   49041.000000  48026.000000
# mean                99.960790     159.905245      8.488061
# std                 23.086579      52.040575      2.313758
# ...

# %%
missing = df.isnull().sum()
missing_percent = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': missing_percent
}).sort_values('Missing %', ascending=False)

missing_df[missing_df['Missing %'] > 0]
# Out:
#                          Missing Count  Missing %
# Weight_kg                         2962      5.924
# Height_cm                         2945      5.890
# Sleep_Hours                       2017      4.034
# Exercise_Hours_Per_Week           1992      3.984
# HbA1c                             1974      3.948
# Daily_Walking_Minutes             1964      3.928
# HDL                               1000      2.000
# Total_Cholesterol                 1000      2.000
# Medication_Adherence              1000      2.000
# LDL                               1000      2.000
# Triglycerides                     1000      2.000
# Blood_Glucose                      959      1.918
# Physical_Activity_Level            500      1.000
# Age                                497      0.994

# %%
numeric = df.select_dtypes(include=['int64', 'float64'])
numeric.head()
# Out:
#    Patient_ID   Age  Height_cm  Weight_kg   BMI  Waist_Circumference_cm  \
# 0           1  32.0      182.1       65.8  19.8                    71.2
# 1           2  42.0      148.5      101.2  45.9                   121.8
# 2           3  89.0      158.1        NaN  37.9                   131.8
# 3           4  87.0      190.9       95.9  26.3                    99.1
# 4           5  27.0      156.9      101.9  41.4                    77.1
#
#    Blood_Glucose  HbA1c  Fasting_Blood_Sugar  Insulin_Level  ...  \
# 0           88.4   10.4                149.5           27.4  ...
# 1          247.3   11.3                199.3           18.3  ...
# 2          141.9    6.3                219.6           23.9  ...
# 3           90.1    7.4                217.7           36.7  ...
# 4           93.8   12.0                153.5           22.3  ...
#
#    Total_Cholesterol   HDL    LDL  Triglycerides  Heart_Rate  \
# 0              138.7  40.1  152.3          250.8         119
# ...

# %%
numeric.isna().sum()
# Out:
# Patient_ID                     0
# Age                          497
# Height_cm                   2945
# Weight_kg                   2962
# BMI                            0
# Waist_Circumference_cm         0
# Blood_Glucose                959
# HbA1c                       1974
# Fasting_Blood_Sugar            0
# Insulin_Level                  0
# Blood_Pressure_Systolic        0
# Blood_Pressure_Diastolic       0
# Total_Cholesterol           1000
# HDL                         1000
# LDL                         1000
# Triglycerides               1000
# Heart_Rate                     0
# Exercise_Hours_Per_Week     1992
# Daily_Walking_Minutes       1964
# Sleep_Hours                 2017
# Daily_Water_Intake_L           0
# Diabetes_Risk_Score            0
# dtype: int64

# %%
category = df.select_dtypes(include=['object', 'category'])
category.head()
# Out:
#   Gender        Country Physical_Activity_Level Diet_Quality  \
# 0   Male         Mexico                Moderate      Healthy
# 1  Other   Saudi Arabia                    High      Healthy
# 2  Other      Argentina                    High      Average
# 3  Other  United States                    High      Average
# 4  Other      Australia                Moderate         Poor
#
#   Sugar_Intake_Level Stress_Level Smoking_Status Alcohol_Consumption  \
# 0                Low     Moderate         Former               Never
# 1                Low     Moderate        Current          Frequently
# 2               High         High          Never          Frequently
# 3               High         High        Current        Occasionally
# 4               High          Low          Never        Occasionally
#
#   Family_History_Diabetes Hypertension Heart_Disease Fatty_Liver PCOS  \
# 0                     Yes           No           Yes         Yes   No
# ...

# %%
category.isna().sum()
# Out:
# Gender                           0
# Country                          0
# Physical_Activity_Level        500
# Diet_Quality                     0
# Sugar_Intake_Level               0
# Stress_Level                     0
# Smoking_Status                   0
# Alcohol_Consumption              0
# Family_History_Diabetes          0
# Hypertension                     0
# Heart_Disease                    0
# Fatty_Liver                      0
# PCOS                             0
# Medication_Adherence          1000
# Work_Type                        0
# Residence_Type                   0
# AI_Health_Recommendation         0
# Doctor_Consultation_Needed       0
# Diabetes_Risk                    0
# dtype: int64

# %%
category.describe()
# Out:
#        Gender   Country Physical_Activity_Level Diet_Quality  \
# count   50000     50000                   49500        50000
# unique      3        25                       3            3
# top      Male  Malaysia                     Low      Healthy
# freq    16718      2083                   16693        16882
#
#        Sugar_Intake_Level Stress_Level Smoking_Status Alcohol_Consumption  \
# count               50000        50000          50000               50000
# unique                  3            3              3                   3
# top                   Low          Low         Former               Never
# freq                16864        16725          16729               16712
#
#        Family_History_Diabetes Hypertension Heart_Disease Fatty_Liver   PCOS  \
# count                    50000        50000         50000       50000  50000
# unique                       2            2             2           2      2
# ...

# %%
numeric.drop(columns = 'Patient_ID').hist( grid = False , figsize = (20,15) , bins = 100 )
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
category_cols = df.select_dtypes(include=['category', 'object']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

for col in category_cols:
    mode_val = df[col].mode()[0] 
    df[col] = df[col].fillna(mode_val)

# %%
df = df.drop( columns = ['Height_cm' ,'Weight_kg' ]) 
df.describe()
# Out:
#          Patient_ID          Age           BMI  Waist_Circumference_cm  \
# count  50000.000000  50000.00000  50000.000000            50000.000000
# mean   25000.500000     53.87238     30.924056               99.960790
# std    14433.901067     21.02487     10.290091               23.086579
# min        1.000000     18.00000     11.900000               60.000000
# 25%    12500.750000     36.00000     22.700000               80.000000
# 50%    25000.500000     54.00000     30.000000               99.800000
# 75%    37500.250000     72.00000     37.800000              119.900000
# max    50000.000000     90.00000     61.700000              140.000000
#
#        Blood_Glucose         HbA1c  Fasting_Blood_Sugar  Insulin_Level  \
# count   50000.000000  50000.000000         50000.000000   50000.000000
# mean      159.905144      8.488532           142.607294      23.476724
# std        51.539079      2.267625            44.681799      12.403841
# ...

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
category_cols = df.select_dtypes(include=['category', 'object']).columns

df[category_cols].describe()
# Out:
#        Gender   Country Physical_Activity_Level Diet_Quality  \
# count   50000     50000                   50000        50000
# unique      3        25                       3            3
# top      Male  Malaysia                     Low      Healthy
# freq    16718      2083                   17193        16882
#
#        Sugar_Intake_Level Stress_Level Smoking_Status Alcohol_Consumption  \
# count               50000        50000          50000               50000
# unique                  3            3              3                   3
# top                   Low          Low         Former               Never
# freq                16864        16725          16729               16712
#
#        Family_History_Diabetes Hypertension Heart_Disease Fatty_Liver   PCOS  \
# count                    50000        50000         50000       50000  50000
# unique                       2            2             2           2      2
# ...

# %% [markdown]
# ## Data Analysis and insights

# %%
plt.figure(figsize=(12, 8))

country_order_asc = df['Country'].value_counts().sort_values(ascending=False).index

sns.countplot(
    data=df,
    y='Country',               
    order=country_order_asc         
)

plt.title('Nationalities in dataset', fontsize=14)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.grid(axis='x', alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(
    data=df,
    x='Diet_Quality' ,
    hue = 'Diabetes_Risk' 
)

plt.show()

# %%
val = category_cols[2:12]


fig , ax  = plt.subplots( 5,2 , figsize = ( 15,20 ) )
ax = ax.flatten()

for idx , var in enumerate ( val ) : 
    order = df[var].value_counts().sort_values(ascending=False).index
    sns.countplot( data = df ,
                   y = var ,
                   order = order, 
                   ax = ax[idx]
                 )

# %%
val =['PCOS', 'Medication_Adherence', 'Work_Type', 
      'Residence_Type',
      'Doctor_Consultation_Needed',
      'Diabetes_Risk']


fig , ax  = plt.subplots( 3,2 , figsize = ( 15,12 ) )
ax = ax.flatten()

for idx , var in enumerate ( val ) : 
    order = df[var].value_counts().sort_values(ascending=False).index
    sns.countplot( data = df ,
                   y = var ,
                   order = order, 
                   ax = ax[idx]
                 )

# %%
plt.figure(figsize = (12,6) )
sns.countplot ( data = df, y='AI_Health_Recommendation',
                order = df['AI_Health_Recommendation'].value_counts().sort_values(ascending=False).index 
              )
plt.show()

# %%
val = category_cols[2:12]


fig , ax  = plt.subplots( 5,2 , figsize = ( 15,20 ) )
ax = ax.flatten()

for idx , var in enumerate ( val ) : 
    order = df[var].value_counts().sort_values(ascending=False).index
    sns.countplot( data = df ,
                   x = var ,
                   hue = 'Diabetes_Risk',
                   order = order, 
                   ax = ax[idx]
                 )

# %%
val =['PCOS', 'Medication_Adherence', 'Work_Type', 
      'Residence_Type',
      'Doctor_Consultation_Needed']


fig , ax  = plt.subplots( 3,2 , figsize = ( 15,12 ) )
ax = ax.flatten()

for idx , var in enumerate ( val ) : 
    order = df[var].value_counts().sort_values(ascending=False).index
    sns.countplot( data = df ,
                   x= var ,
                   order = order,
                   hue = 'Diabetes_Risk' ,
                   ax = ax[idx]
                 )

# %%
corr = df[numeric_cols].corr()
plt.figure( figsize = (12,8))
sns.heatmap( corr , cmap = 'Blues' , linewidths = 0.5 , linecolor= 'black' ) 
plt.xticks(rotation = 90 )
plt.show()

# %%
df[numeric_cols].hist( figsize = (15,20))

plt.show()

# %% [markdown]
# Very Random Dataset

# %%
val = category_cols[2:12]


fig , ax  = plt.subplots( 5,2 , figsize = ( 15,20 ) )
ax = ax.flatten()

for idx , var in enumerate ( val ) : 
    order = df[var].value_counts().sort_values(ascending=False).index
    sns.barplot( data = df ,
                   x = var ,
                    y = 'Age',
                   hue = 'Diabetes_Risk',
                   order = order, 
                   ax = ax[idx]
                 )

# %% [markdown]
# There is no significant relationship and model cannot learn pattern on uniform distributions
